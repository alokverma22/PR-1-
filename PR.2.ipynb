# %%
print("Welcome to the Pattern Generator and Number Analyzer!")

choice = ""

while choice != "3":
    print("\nSelect an option:")
    print("1. Generate a Pattern")
    print("2. Analyze a Range of Numbers")
    print("3. Exit")
    
    choice = input("Enter your choice: ")
    
    if choice == "1":
        rows = int(input("Enter the number of rows for the pattern: "))
        print("\nPattern:")
        for i in range(1, rows + 1):
            print("*" * i)
            
    if choice == "2":
        start = int(input("Enter the start of the range: "))
        end = int(input("Enter the end of the range: "))
        
        total_sum = 0
        num = start
        
        while num <= end:
            if num % 2 == 0:
                print("Number", num, "is Even")
            else:
                print("Number", num, "is Odd")
            total_sum = total_sum + num
            num = num + 1
            
        print("Sum of all numbers from", start, "to", end, "is:", total_sum)

    if choice == "3":
        print("Exiting the program. Goodbye1")
# Out:
# Welcome to the Pattern Generator and Number Analyzer!
#
# Select an option:
# 1. Generate a Pattern
# 2. Analyze a Range of Numbers
# 3. Exit
# Enter your choice:  1
# Enter the number of rows for the pattern:  7
# Pattern:
# *
# **
# ***
# ****
# *****
# ******
# *******
#
# Select an option:
# 1. Generate a Pattern
# 2. Analyze a Range of Numbers
# 3. Exit
# Enter your choice:  2
# Enter the start of the range:  9
# Enter the end of the range:  16
# Number 9 is Odd
# Number 10 is Even
# Number 11 is Odd
# Number 12 is Even
# Number 13 is Odd
# Number 14 is Even
# Number 15 is Odd
# Number 16 is Even
# Sum of all numbers from 9 to 16 is: 100
#
# Select an option:
# 1. Generate a Pattern
# 2. Analyze a Range of Numbers
# 3. Exit
# Enter your choice:  3
# Exiting the program. Goodbye1
